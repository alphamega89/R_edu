# %% [markdown]
# <a href="https://colab.research.google.com/github/alphamega89/R_edu/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import needed modules
# !pip install quandl

import quandl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#get adjusted closing prices of 5 selected companies with Quandl

quandl.ApiConfig.api_key = 'ywmtY79AU8SwXDXz4QjC' #copy and paste your api key here
selected = ['CNP', 'F', 'WMT', 'GE', 'TSLA'] # selected assets list
data = quandl.get_table('WIKI/PRICES', ticker = selected,
                       qopts = { 'columns': ['date', 'ticker', 'adj_close'] },
                       date = { 'gte': '2014-1-1', 'lte': '2019-7-1' }, paginate=True)
print(data.head())
print(data.tail())


# reorganise data pulled by setting date as index with
# columns of tickers and their corresponding adjusted prices
clean = data.set_index('date')
table = clean.pivot(columns='ticker')
print(table.head())
print(table.tail())


# calculate daily and annual returns of the stocks
returns_daily = table.pct_change()
returns_annual = returns_daily.mean() * 252 # use average instead of expected value
print(returns_daily.tail())
print(returns_annual)


# get daily and covariance of returns of the stock
cov_daily = returns_daily.cov()
cov_annual = cov_daily * 252
#returns_daily.head()
print(cov_annual)
# Out:
# Requirement already satisfied: quandl in /usr/local/lib/python3.6/dist-packages (3.4.8)
# Requirement already satisfied: pyasn1 in /usr/local/lib/python3.6/dist-packages (from quandl) (0.4.5)
# Requirement already satisfied: pandas>=0.14 in /usr/local/lib/python3.6/dist-packages (from quandl) (0.24.2)
# Requirement already satisfied: requests>=2.7.0 in /usr/local/lib/python3.6/dist-packages (from quandl) (2.21.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from quandl) (2.5.3)
# Requirement already satisfied: ndg-httpsclient in /usr/local/lib/python3.6/dist-packages (from quandl) (0.5.1)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.6/dist-packages (from quandl) (0.3.1)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.6/dist-packages (from quandl) (1.16.4)
# Requirement already satisfied: more-itertools<=5.0.0 in /usr/local/lib/python3.6/dist-packages (from quandl) (5.0.0)
# Requirement already satisfied: pyOpenSSL in /usr/local/lib/python3.6/dist-packages (from quandl) (19.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from quandl) (1.12.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.14->quandl) (2018.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->quandl) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->quandl) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->quandl) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.7.0->quandl) (3.0.4)
# Requirement already satisfied: cryptography>=2.3 in /usr/local/lib/python3.6/dist-packages (from pyOpenSSL->quandl) (2.7)
# Requirement already satisfied: asn1crypto>=0.21.0 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.3->pyOpenSSL->quandl) (0.24.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.3->pyOpenSSL->quandl) (1.12.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.3->pyOpenSSL->quandl) (2.19)
#            date ticker  adj_close
# None
# 0    2018-03-27    WMT      86.05
# 1    2018-03-26    WMT      87.50
# 2    2018-03-23    WMT      85.42
# 3    2018-03-22    WMT      87.14
# 4    2018-03-21    WMT      88.18
#            date ticker  adj_close
# None
# 5320 2014-01-08    CNP  19.132992
# 5321 2014-01-07    CNP  19.334039
# 5322 2014-01-06    CNP  19.132992
# 5323 2014-01-03    CNP  19.107861
# 5324 2014-01-02    CNP  19.116238
#             adj_close
# ticker            CNP          F         GE    TSLA        WMT
# date
# 2014-01-02  19.116238  12.726742  24.266002  150.10  71.343743
# 2014-01-03  19.107861  12.784441  24.248354  149.56  71.108673
# 2014-01-06  19.132992  12.842140  24.054226  147.00  70.710863
# 2014-01-07  19.334039  12.677286  24.080698  149.36  70.927850
# 2014-01-08  19.132992  12.809169  24.010106  151.28  70.367299
#            adj_close
# ticker           CNP      F     GE    TSLA    WMT
# date
# 2018-03-21     26.84  11.10  13.88  316.53  88.18
# 2018-03-22     26.73  10.75  13.35  309.10  87.14
# 2018-03-23     26.50  10.56  13.07  301.54  85.42
# 2018-03-26     26.84  10.83  12.89  304.18  87.50
# 2018-03-27     27.09  10.83  13.44  279.18  86.05
#            adj_close
# ticker           CNP         F        GE      TSLA       WMT
# date
# 2018-03-21  0.001119  0.010009  0.017595  0.019256  0.002615
# 2018-03-22 -0.004098 -0.031532 -0.038184 -0.023473 -0.011794
# 2018-03-23 -0.008605 -0.017674 -0.020974 -0.024458 -0.019738
# 2018-03-26  0.012830  0.025568 -0.013772  0.008755  0.024350
# 2018-03-27  0.009314  0.000000  0.042669 -0.082188 -0.016571
#            ticker
# adj_close  CNP       0.100251
#            F        -0.012811
#            GE       -0.119566
#            TSLA      0.229452
#            WMT       0.062445
# dtype: float64
#                  adj_close
# ticker                 CNP         F        GE      TSLA       WMT
#           ticker
# adj_close CNP     0.035287  0.010835  0.011631  0.014918  0.008472
#           F       0.010835  0.050508  0.020797  0.023845  0.009717
#           GE      0.011631  0.020797  0.040694  0.018417  0.008910
#           TSLA    0.014918  0.023845  0.018417  0.165404  0.012254
#           WMT     0.008472  0.009717  0.008910  0.012254  0.036058

# %%
# get daily and covariance of returns of the stock
cov_daily = returns_daily.corr()
cov_annual = cov_daily * 252
#returns_daily.head()
print(cov_annual)
# Out:
#                    adj_close
# ticker                   CNP           F          GE        TSLA         WMT
#           ticker
# adj_close CNP     252.000000   64.677233   77.348266   49.208378   59.852781
#           F        64.677233  252.000000  115.599946   65.743428   57.380782
#           GE       77.348266  115.599946  252.000000   56.570718   58.612860
#           TSLA     49.208378   65.743428   56.570718  252.000000   39.986126
#           WMT      59.852781   57.380782   58.612860   39.986126  252.000000

# %%
# empty lists to store returns, volatility and weights of imaginary portfolios
port_returns = []
port_volatility = []
stock_weights = []

# set the number of combinations for imaginary portfolios
num_assets = len(selected)
num_portfolios = 50000 # of simulated portfolio
wmin = 0.05 # minimum portfolio weights per asset
# populate the empty lists with each portfolio returns,risk and weights
for single_portfolio in range(num_portfolios):
    weights = np.random.random(num_assets) 
    # Return random floats in the half-open interval [0.0, 1.0)
    # weights = np.random.standard_normal(num_assets)
    weights /= np.sum(weights) # weights = weights/np.sum(weights)
    weights = weights*(1-wmin*num_assets) + wmin
    returns = np.dot(weights, returns_annual)
    volatility = np.sqrt(np.dot(weights.T, np.dot(cov_annual, weights)))
    port_returns.append(returns)
    port_volatility.append(volatility)
    stock_weights.append(weights)

# a dictionary for Returns and Risk values of each portfolio
portfolio = {'Returns': port_returns,
             'Volatility': port_volatility}

# extend original dictionary to accommodate each ticker and weight in the portfolio
for counter,symbol in enumerate(selected):
    portfolio[symbol+' weight'] = [weight[counter] for weight in stock_weights]

# make a nice dataframe of the extended dictionary
df = pd.DataFrame(portfolio)

# get better labels for desired arrangement of columns
column_order = ['Returns', 'Volatility'] + [stock+' weight' for stock in selected]

# reorder dataframe columns
df = df[column_order]

print(df.head())
print(df.tail())
# Out:
#     Returns  Volatility  CNP weight  ...  WMT weight  GE weight  TSLA weight
# 0  0.044617    0.148992    0.221766  ...    0.203621   0.159336     0.205842
# 1  0.067087    0.147992    0.357354  ...    0.144527   0.163928     0.202108
# 2  0.056638    0.186550    0.058521  ...    0.225723   0.311335     0.152873
# 3  0.035772    0.155471    0.138202  ...    0.261963   0.186020     0.210712
# 4  0.035494    0.151017    0.134100  ...    0.210977   0.153832     0.244478
#
# [5 rows x 7 columns]
#         Returns  Volatility  CNP weight  ...  WMT weight  GE weight  TSLA weight
# 49995  0.062187    0.146552    0.361679  ...    0.121895   0.140249     0.174630
# 49996  0.065369    0.179113    0.066692  ...    0.240662   0.306997     0.291773
# 49997  0.039586    0.177472    0.121317  ...    0.386152   0.283595     0.148822
# 49998  0.013104    0.167273    0.069268  ...    0.216226   0.133959     0.115782
# 49999  0.050741    0.164866    0.081760  ...    0.254735   0.243629     0.298713
#
# [5 rows x 7 columns]

# %%
# plot the efficient frontier with a scatter plot
plt.style.use('seaborn')
df.plot.scatter(x='Volatility', y='Returns', figsize=(10, 8), grid=True, 
#                color='turquoise',edgecolors='turquoise')
                color='#81D8D0',edgecolors='turquoise')
#                color='red',edgecolors='turquoise')
plt.xlabel('Volatility (Std. Deviation)')
plt.ylabel('Expected Returns')
plt.title('Efficient Frontier')
plt.show()

# %%
port_returns = []
port_volatility = []
sharpe_ratio = []
stock_weights = []

# set the number of combinations for imaginary portfolios
num_assets = len(selected)
num_portfolios = 50000

#set random seed for reproduction's sake
np.random.seed(101)

# populate the empty lists with each portfolios returns,risk and weights
rf = 0.015 # risk free rate
for single_portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights /= np.sum(weights)
    weights = weights*(1-wmin*num_assets) + wmin
    returns = np.dot(weights, returns_annual)
    volatility = np.sqrt(np.dot(weights.T, np.dot(cov_annual, weights)))
    sharpe = (returns - rf) / volatility
    sharpe_ratio.append(sharpe)
    port_returns.append(returns)
    port_volatility.append(volatility)
    stock_weights.append(weights)

# a dictionary for Returns and Risk values of each portfolio
portfolio = {'Returns': port_returns,
             'Volatility': port_volatility,
             'Sharpe Ratio': sharpe_ratio}

# extend original dictionary to accomodate each ticker and weight in the portfolio
for counter,symbol in enumerate(selected):
    portfolio[symbol+' Weight'] = [Weight[counter] for Weight in stock_weights]

# make a nice dataframe of the extended dictionary
df = pd.DataFrame(portfolio)

# get better labels for desired arrangement of columns
column_order = ['Returns', 'Volatility', 'Sharpe Ratio'] + [stock+' Weight' for stock in selected]

# reorder dataframe columns
df = df[column_order]

print(df.head())
# Out:
#     Returns  Volatility  Sharpe Ratio  ...  WMT Weight  GE Weight  TSLA Weight
# 0  0.059837    0.143913      0.311559  ...    0.060828   0.115223     0.310583
# 1  0.051238    0.164474      0.220327  ...    0.277501   0.233695     0.098356
# 2  0.084269    0.165120      0.419503  ...    0.098046   0.257514     0.305029
# 3  0.065430    0.186588      0.270274  ...    0.285186   0.334068     0.157643
# 4  0.060363    0.148344      0.305797  ...    0.073066   0.115590     0.138948
#
# [5 rows x 8 columns]

# %%
# plot frontier, max sharpe & min Volatility values with a scatterplot
plt.style.use('seaborn-dark')
df.plot.scatter(x='Volatility', y='Returns', c='Sharpe Ratio',
                cmap='coolwarm', edgecolors='grey', figsize=(10, 8), grid=True)
#cmap='RdYlGn'
plt.xlabel('Volatility (Std. Deviation)')
plt.ylabel('Expected Returns')
plt.title('Efficient Frontier')
plt.show()

# %%
# find min Volatility & max sharpe values in the dataframe (df)
min_volatility = df['Volatility'].min()
max_sharpe = df['Sharpe Ratio'].max()

# use the min, max values to locate and create the two special portfolios
sharpe_portfolio = df.loc[df['Sharpe Ratio'] == max_sharpe]
min_variance_port = df.loc[df['Volatility'] == min_volatility]

# plot frontier, max sharpe & min Volatility values with a scatterplot
plt.style.use('seaborn-dark')
df.plot.scatter(x='Volatility', y='Returns', c='Sharpe Ratio',
                cmap='hot', edgecolors='grey', figsize=(15, 8), grid=True)
plt.scatter(x=sharpe_portfolio['Volatility'], y=sharpe_portfolio['Returns'], c='teal', marker='D', s=200)
plt.scatter(x=min_variance_port['Volatility'], y=min_variance_port['Returns'], c='b', marker='D', s=200 )
# https://matplotlib.org/api/markers_api.html
plt.xlabel('Volatility (Std. Deviation)')
plt.ylabel('Expected Returns')
plt.title('Efficient Frontier')
plt.show()

# %%
print(min_variance_port.T)
print(sharpe_portfolio.T)
# Out:
#                  41218
# Returns       0.042571
# Volatility    0.135035
# Sharpe Ratio  0.204175
# CNP Weight    0.333920
# F Weight      0.105344
# WMT Weight    0.182750
# GE Weight     0.052044
# TSLA Weight   0.325942
#                    453
# Returns       0.130178
# Volatility    0.205757
# Sharpe Ratio  0.559777
# CNP Weight    0.352502
# F Weight      0.054546
# WMT Weight    0.053129
# GE Weight     0.408255
# TSLA Weight   0.131569
